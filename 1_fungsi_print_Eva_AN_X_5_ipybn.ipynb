# %% [markdown]
# <a href="https://colab.research.google.com/github/evaardziyatunnisaaa2025-jpg/KKA-X-SEMESTER-1/blob/main/1_fungsi_print_Eva_AN_X_5_ipybn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Menampilkan Teks Bebas

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Eva Ardziyatun Nisa")
# Out:
# Eva Ardziyatun Nisa

# %% [markdown]
# #2. Menampilkan nilai variabel

# %%
beratBadan = 48

print(beratBadan)
# Out:
# 48

# %%
tinggiBadan = 155

print(tinggiBadan)
# Out:
# 155

# %%
Nama = "Eva Ardziyatun Nisa"

print(Nama)
# Out:
# Eva Ardziyatun Nisa

# %% [markdown]
# #3.Menampilkan Teks Bebas dan Nilai Variabel

# %%
print("Halo nama saya", Nama, ".berat badan saya", beratBadan, " Kg")
# Out:
# Halo nama saya Eva Ardziyatun Nisa .berat badan saya 48  Kg

# %%
print("Halo nama saya"+ Nama+ ".berat badan saya"+str(beratBadan)+" Kg")
# Out:
# Halo nama sayaEva Ardziyatun Nisa.berat badan saya48 Kg

# %%
print(f"Hallo nama saya {Nama }.Berat badan saya{beratBadan}Kg.")
# Out:
# Hallo nama saya Eva Ardziyatun Nisa.Berat badan saya48Kg.

# %% [markdown]
# #4.Escape character

# %%
print("Nama:Eva ardziyatun nisa")
print("Kelas:X.5")
print("no.absen:12")
# Out:
# Nama:Eva ardziyatun nisa
# Kelas:X.5
# no.absen:12

# %%
print("Nama:Eva ardziyatun nisa\nKelas:X.5\nNo.absen:12")
# Out:
# Nama:Eva ardziyatun nisa
# Kelas:X.5
# No.absen:12

# %%
print("""Nama\t\t: Eva ardziyatun nisa
Kelas\t\t: X-5
No. Absen\t: 12""")
# Out:
# Nama		: Eva ardziyatun nisa
# Kelas		: X-5
# No. Absen	: 12

# %%
print('Nama Saya Ja\'far Shodiq')
# Out:
# Nama Saya Ja'far Shodiq

# %%
print("Nama Saya Ja'far Shodiq")
# Out:
# Nama Saya Ja'far Shodiq

# %%
print("Nama Saya Ja\'far Shodiq")
# Out:
# Nama Saya Ja'far Shodiq

# %%
print('Bu Shinta berkata, "Tolong perhatikan TV dan Saya."')
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print("Bu Shinta berkata, \"Tolong perhatikan TV dan Saya.\"")
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print("Lokasi file tugas KKA adalah di Local Disk C:\\KKA\\Tugas")
# Out:
# Lokasi file tugas KKA adalah di Local Disk C:\KKA\Tugas

# %%
print('''Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2
yang disimpan di file D:\\MAN Demak\\Jadwal Piket.".

Senin      Selasa      Rabu
Jielo      Hasbi       Naufal
Azam       Aida        A'inun
''')
# Out:
# Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2
# yang disimpan di file D:\MAN Demak\Jadwal Piket.".
#
# Senin      Selasa      Rabu
# Jielo      Hasbi       Naufal
# Azam       Aida        A'inun

# %% [markdown]
# # Parameter fungsi print

# %%
nama_siswa_1="Jielo"
nama_siswa_2="Aida"
nama_siswa_3="Dani"

print(nama_siswa_1,end="-")
print(nama_siswa_2,end="-")
print(nama_siswa_3)
# Out:
# Jielo-Aida-Dani

# %%
nama_siswa_1 ="Jielo"
nama_siswa_2 ="Aida"
nama_siswa_3 ="Dani"
nama_siswa_4 ="Nurul"

# %%
print(nama_siswa_4,end="/")
print(nama_siswa_2,end="/")
print(nama_siswa_1,end="/")
print(nama_siswa_3)
# Out:
# Nurul/Aida/Jielo/Dani

# %%
nama_siswa_5="Hasbi"
nama_siswa_6="Habibi"
nama_siswa_7="Rendra"
nama_siswa_8="Naufal"
print(nama_siswa_8,nama_siswa_7,nama_siswa_5,nama_siswa_6,sep="-")
# Out:
# Naufal-Rendra-Hasbi-Habibi

# %%
nama_siswa_5="Hasbi"
nama_siswa_6="Habibi"
nama_siswa_7="Rendra"
nama_siswa_8="Naufal"

# %%
print(nama_siswa_5,nama_siswa_8,nama_siswa_7,nama_siswa_6,nama_siswa_8,sep="*")
print(nama_siswa_7,nama_siswa_6,nama_siswa_5,nama_siswa_7,nama_siswa_7,sep="-")
# Out:
# Hasbi*Naufal*Rendra*Habibi*Naufal
# Rendra-Habibi-Hasbi-Rendra-Rendra
