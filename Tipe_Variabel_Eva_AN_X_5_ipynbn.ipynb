# %% [markdown]
# <a href="https://colab.research.google.com/github/evaardziyatunnisaaa2025-jpg/KKA-X-SEMESTER-1/blob/main/Tipe_Variabel_Eva_AN_X_5_ipynbn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Eva Ardziyatun nisa Nisa
#
# Kelas:X.5
#
# No.absen:12

# %% [markdown]
# #Konsep dasar Variabel

# %%
print("evaardziyatunnisaaa.2025@gmail.com")
print("evaardziyatunnisaaa.2025@gmail.com")
print("evaardziyatunnisaaa.2025@gmail.com")
# Out:
# evaardziyatunnisaaa.2025@gmail.com
# evaardziyatunnisaaa.2025@gmail.com
# evaardziyatunnisaaa.2025@gmail.com

# %%
email_user_1="evaardziyatunnisaaa.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# evaardziyatunnisaaa.2025@gmail.com
# evaardziyatunnisaaa.2025@gmail.com
# evaardziyatunnisaaa.2025@gmail.com

# %% [markdown]
# #Peraturan penulisan variabel

# %%
email_user_2="hitamhitam@gmail.com"

print(email_user_2)
# Out:
# hitamhitam@gmail.com

# %%
#Hanya boleh menggunakan angka, huruf dan underscore


email_user_2 ="hitamhitam@gmail.com"

print(email_user_2)
# Out:
# hitamhitam@gmail.com

# %%
3_email_user="adityawiata@gmail.com"
 print(3_email_user)
# Out:
#   File "/tmp/ipython-input-3071601459.py", line 1
#     3_email_user="adityawiata@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_2="Romamancing@gmail.com"

print(email_user_2)
# Out:
# Romamancing@gmail.com

# %%
#tidak boleh didahului angka
email_user_3="adityawiata"

print(email_user_3)
# Out:
# adityawiata

# %%
#penulisan variabel sensitif terhadap kapital

Email_user_4 = "Fatimahaaa@gmail.com"

print(Email_user_4)
# Out:
# Fatimahaaa@gmail.com

# %%
if = "upinipin@gmail.com"

print (if)
# Out:
#   File "/tmp/ipython-input-3153527205.py", line 1
#     if = "upinipin@gmail.com"
#        ^
# SyntaxError: invalid syntax

# %%
If= "upinipin@gmail.com"

print (If)

# %%
Print = "muhammadsyakoer@gmail.com"

print(Print)
# Out:
# muhammadsyakoer@gmail.com

# %%
#Penulisan Variabel Sensitif Terhadap Kapital

Print = "muhammadsyakoer@gmail.com"

print(Print)
# Out:
# muhammadsyakoer@gmail.com

# %%
#Harus deskripsi meski tidak eror

 _ ="marshanda@gmail.com"


print(_)
# Out:
#   File "/tmp/ipython-input-187549934.py", line 3
#     _ ="marshanda@gmail.com"
#     ^
# IndentationError: unexpected indent

# %%
_ ="marshanda@gmail.com"

print (_)
# Out:
# marshanda@gmail.com

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3925571382.py in <cell line: 0>()
# ----> 1 print(i)
#
# NameError: name 'i' is not defined

# %% [markdown]
# #Jenis-jenis operator aritmatika pada python

# %%
#Penjumlahan
iphone_rolan = 21
iphone_gibran = 4

total_iphone = iphone_rolan + iphone_gibran

print(total_iphone)
# Out:
# 25

# %%
#Pengurangan

iphone_rolan = 21
iphone_gibran = 4

selisih_iphone = iphone_rolan - iphone_gibran

print(selisih_iphone)
# Out:
# 17

# %%
#Pengurangan
iphone_rolan = 21
iphone_gibran = 4

selisih_iphone = iphone_rolan - iphone_gibran

print(selisih_iphone)
# Out:
# 17

# %%
#perkalian
jumlah_dus = 5
jumlah_botol_per_dus = 10

total_botol = jumlah_dus * jumlah_botol_per_dus

print(total_botol)
# Out:
# 50

# %%
#Pembagian
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan / iphone_gibran

print(pembagian_iphone)
# Out:
# 5.25

# %%
#Pembagian bulat
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan // iphone_gibran

print(pembagian_iphone)
# Out:
# 5

# %%
#sisa bagi

iphone_rolan = 21
jumlah_anak_yatim = 5

sisa_bagi_iphone = iphone_rolan % jumlah_anak_yatim

print(sisa_bagi_iphone)
# Out:
# 1

# %%
#perpangkatan
sisi = 5

luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# 25

# %%
sisi = 2
volume_kubus = sisi ** 3

print(volume_kubus)
# Out:
# 8

# %%
luas_persegi = 25

sisi = luas_persegi ** (1/2)

print(sisi)
# Out:
# 5.0

# %%
volume_kubus = 8
sisi = volume_kubus ** (1/3)

print(sisi)
# Out:
# 2.0

# %% [markdown]
# #Jenis Tipe Variabel pada Python

# %%
#Float
x = 17.5
print(x)
type(x)
# Out:
# 17.5
# float

# %%
#Integer
y = 8
print(y)
type(y)
# Out:
# 8
# int

# %%
#String
z = "shinta"
print(z)
type(z)
# Out:
# shinta
# str

# %%
#Boolean
p = True
print(p)
type(p)
# Out:
# True
# bool

# %%
r = -2.5
print(r)
type(r)
# Out:
# -2.5
# float

# %%
s = 5.1
print(s)
type(s)
# Out:
# 5.1
# float

# %%
k = '%7akh3.'
print(k)
type(k)
# Out:
# %7akh3.
# str

# %% [markdown]
# #Mengubah Tipe Data

# %%
a = 25
print(a)
type(a)
# Out:
# 25
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 25.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 25.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = True
print(b)
type(b)
# Out:
# True
# bool

# %%
b = int(b)
print(b)
type(b)
# Out:
# 1
# int

# %%
b = float(b)
print(b)
type(b)
# Out:
# 1.0
# float

# %%
b = str(b)
print(b)
type(b)
# Out:
# 1.0
# str

# %%
c = False
print(c)
type(c)
# Out:
# False
# bool

# %%
c = float(c)
print(c)
type(c)
# Out:
# 0.0
# float

# %%
c = int(c)
print(c)
type(c)
# Out:
# 0
# int

# %%
c = str(c)
print(c)
type(c)
# Out:
# 0
# str

# %% [markdown]
# #Operator perbandingan

# %%
print(6>0)
# Out:
# True

# %%
print(7>9)
# Out:
# False

# %%
print(8<9)
# Out:
# True

# %%
print(8<4)
# Out:
# False

# %%
print (5>=5)
# Out:
# True

# %%
print (6>=5)
# Out:
# True

# %%
print(3==2)
# Out:
# False

# %%
print (3==3)
# Out:
# True

# %%
print (5!=5)
# Out:
# False

# %%
a=8
b=9
print(b<a)
# Out:
# False

# %%
print (9<8)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(7!=8 and 8>2)
# Out:
# True

# %%
print(7==8 and 8>2)
# Out:
# False

# %%
print(7==8 or 8>2)
# Out:
# True

# %%
print(7==8 or 8>2)
# Out:
# True

# %%
print(not 7==8)
# Out:
# True

# %%
m = 10
n = 20
p = 30

print(m<n and p>m)
# Out:
# True

# %%
print(not (m<n or p>m))
# Out:
# False
