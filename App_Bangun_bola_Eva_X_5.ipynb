# %% [markdown]
# <a href="https://colab.research.google.com/github/evaardziyatunnisaaa2025-jpg/KKA-X-SEMESTER-1/blob/main/App_Bangun_bola_Eva_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama kelompok:lele terbang
#
# Nama         :Eva ardziyatun nisa
#
# Kelas        :X.5
#
# No. Absen    :12

# %%
#program menghitung volume bola


#Meminta input dari pengguna

π = 22/7
r =float(input("masukan r bola(cm) : "))

#menghitung volume bola
volume=3/4*π*r**3

#menampilkan hasil
print(f"volume bola adalah:{volume}cm³.")
# Out:
# masukan r bola(cm) : 7
# volume bola adalah:808.5cm³.
